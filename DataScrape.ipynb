# %%
from bs4 import BeautifulSoup
import re
import requests

# url = "https://hanselltierney.catsone.com/careers/50780-General/jobs/12139850-Senior-Data-Scientist-Statistical-and-Predictive-Modeling?host=hanselltierney.catsone.com&location%5B0%5D=Bellevue%2C%20WA&location%5B1%5D=Bothell%2C%20WA&location%5B2%5D=Kent%2C%20WA&location%5B3%5D=Kirkland%2C%20WA&location%5B4%5D=Seattle%2C%20WA"
# url = "https://careers.airbnb.com/positions/1724499/"
#url = "https://ea.gr8people.com/index.gp?method=cappportal.showJob&layoutid=2092&inp1541=&opportunityid=156134&sid=https://www.ea.com/careers/careers-overview"
url = 'https://www.basketball-reference.com/teams/MIL/2019/splits/'

def airbnb(content):
    for div in content.find_all('div'):
        print(div.get_text())

page = requests.get(url)
if page.status_code == 200:
    print("Ok to scrape")
else: 
    print(page.status_code)
# Out:
# Ok to scrape

# %%
content = BeautifulSoup(page.content, 'html.parser')
print(content.prettify())
# Out:
# <!DOCTYPE html>
# <html class="no-js" data-root="/home/bbr/www" data-version="klecko-" itemscope="" itemtype="https://schema.org/WebSite" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="ie=edge" http-equiv="x-ua-compatible"/>
#   <meta content="width=device-width, initial-scale=1.0, maximum-scale=2.0" name="viewport">
#    <link href="https://d2p3bygnnzw9w3.cloudfront.net/req/201904231" rel="dns-prefetch"/>
#    <!-- no:cookie fast load the css.           -->
#    <link crossorigin="" href="https://d2p3bygnnzw9w3.cloudfront.net" rel="preconnect"/>
#    <link crossorigin="" href="https://d2cwpp38twqe55.cloudfront.net" rel="preconnect"/>
#    <style>
# ...
